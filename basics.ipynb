# %% [markdown]
# <a href="https://colab.research.google.com/github/relinxx/deep-learning-practice/blob/practice-on-google-colab/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
